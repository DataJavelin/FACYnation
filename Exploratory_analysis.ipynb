# %% [markdown]
# <img src="https://pbs.twimg.com/profile_images/969600936321736704/WrwKmb8y_400x400.jpg" width="200" height="200" />
#
# # FACYnation Hack day
# This notebook contains an explanation of the data being used as part of the FACYnation Hack day.

# %%
import pandas as pd
import pylab as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## `clim_files`
# There are precipitation and temperature climatology files for each crop. In it contain monthly total precipitation and mean temperature measurements for each region (not sure what the season responds to). As an example, lets read in the precipitation and temperature files for maize.

# %%
ls ./Crop_data_files/clim_file
# Out:
# Icon?                           temp_climatology_Maize.csv
# precip_climatology_Maize.csv    temp_climatology_Rice.csv
# precip_climatology_Rice.csv     temp_climatology_Soybean.csv
# precip_climatology_Soybean.csv  temp_climatology_Wheat.csv
# precip_climatology_Wheat.csv

# %%
clim_precip_maize=pd.read_table('./Crop_data_files/clim_file/precip_climatology_Maize.csv')
clim_precip_maize.rename(columns = {'Unnamed: 0':'Crop_season_location'}, inplace = True)
clim_temp_maize=pd.read_table('./Crop_data_files/clim_file/temp_climatology_Maize.csv')
clim_temp_maize.rename(columns = {'Unnamed: 0':'Crop_season_location'}, inplace = True)

# %%
clim_precip_maize[0:10]
# Out:
#           Crop_season_location        Jan        Feb        Mar         Apr  \
# 0        Maize_Spring_USA_Ohio  52.761777  50.045758  76.796623   98.220427
# 1   Maize_Spring_USA_Minnesota   7.017376   8.554667  32.434670   74.904777
# 2     Maize_Summer_China_Henan  10.941580  18.128238  34.362643   47.226727
# 3  Maize_Spring_China_Liaoning   0.700592   1.918669   8.140692   29.887255
# 4  Maize_Summer_China_Shandong   5.886620  10.701122  17.888108   34.647167
# 5    Maize_Spring_USA_Illinois  39.311173  40.544719  72.166429  104.157911
# 6     Maize_Spring_USA_Indiana  54.515473  50.966315  81.035918  106.495404
# 7    Maize_Summer_China_Shanxi   0.559319   2.609655  11.298355   21.841122
# 8    Maize_Spring_USA_Nebraska   7.091140  11.563000  40.769852   77.113913
# 9        Maize_Spring_USA_Iowa  12.389073  16.021303  48.048641   94.298929
#
#           May         Jun         Jul         Aug        Sep        Oct  \
# 0  116.476743  104.450713  108.432234   91.333840  83.734165  78.038004
# 1   97.957333  120.396073  103.540149  108.179273  84.877427  61.817174
# 2   78.348534   97.348101  186.891395  147.476387  78.204810  48.621850
# 3   48.340478   90.430823  179.457812  138.929664  49.345632  31.244514
# 4   60.514011   84.299045  192.553820  153.303092  63.667248  34.538604
# 5  122.487176  115.325049  101.626312   96.852235  88.513945  82.492127
# 6  126.852435  112.202063  107.939666   93.822779  87.749408  86.492515
# 7   41.849433   62.426302  117.259387  114.150799  63.690989  33.382486
# 8  109.008308  117.617110   90.010977   95.086835  76.735491  55.951674
# 9  118.813263  124.363010  108.797291  107.308399  88.867747  68.185133
#
#          Nov        Dec
# 0  81.754893  68.792176
# 1  28.888944  11.490966
# 2  30.025877   9.343714
# 3  11.136053   2.179711
# 4  20.966099   7.642590
# 5  84.322508  56.244241
# 6  89.763421  70.171306
# 7  12.394215   1.133610
# 8  27.626102  13.630952
# 9  45.713214  23.084986

# %%
clim_temp_maize[0:10]
# Out:
#           Crop_season_location        Jan       Feb       Mar        Apr  \
# 0        Maize_Spring_USA_Ohio  -2.071370 -0.417198  4.642302  11.019271
# 1   Maize_Spring_USA_Minnesota  -8.749417 -6.073833  0.654440   8.569846
# 2     Maize_Summer_China_Henan   1.154793  3.577543  8.906664  15.586943
# 3  Maize_Spring_China_Liaoning -12.100253 -7.588759  0.248221   9.178736
# 4  Maize_Summer_China_Shandong  -0.658903  1.827582  7.404073  14.390726
# 5    Maize_Spring_USA_Illinois  -2.593461 -0.359544  5.629671  12.030782
# 6     Maize_Spring_USA_Indiana  -1.896945  0.074153  5.481943  11.751006
# 7    Maize_Summer_China_Shanxi  -5.833626 -2.348679  3.905696  11.084932
# 8    Maize_Spring_USA_Nebraska  -3.626673 -1.340699  4.730650  11.072987
# 9        Maize_Spring_USA_Iowa  -5.344238 -2.939681  3.710271  10.584489
#
#          May        Jun        Jul        Aug        Sep        Oct       Nov  \
# 0  16.556568  21.341552  23.528094  22.537785  18.666326  12.348698  6.295049
# 1  15.323615  20.465008  22.780350  21.419577  17.035088   9.996546  1.431298
# 2  20.823192  25.362553  27.162466  26.051910  21.547124  16.148739  9.171493
# 3  16.066126  20.918395  23.612906  22.630298  16.871221   9.193697 -0.654138
# 4  20.004364  24.481713  26.601902  25.782575  21.477751  15.836687  8.055217
# 5  17.683070  22.640778  24.706824  23.646445  19.489199  13.226610  6.337894
# 6  17.337501  22.201466  24.244437  23.238411  19.290001  12.964631  6.680281
# 7  16.810413  20.896184  22.857834  21.361878  16.458446  10.294326  2.619576
# 8  16.934094  22.232746  24.877917  23.716845  19.236255  12.410369  4.466055
# 9  16.701439  21.826338  24.067030  22.818048  18.522317  11.878622  3.996469
#
#         Dec
# 0  0.336915
# 1 -6.580419
# 2  3.091786
# 3 -9.176574
# 4  1.484075
# 5 -0.409052
# 6  0.421379
# 7 -3.844958
# 8 -2.383827
# 9 -3.509838

# %% [markdown]
# ## `"crop"_met_anoms`
# The other directories contain processed anomlies for each "crop".
#
# Anomalies are defined as monthly mean - climatological monthly mean:$$\frac{1}{Days\ in\ m}\sum_{i=1}^{Days\ in\ m}T_{i,m} - \frac{1}{24}\sum_{y=1980}^{2014}\bar{T_{y,m}}$$
#
# As an example lets read in the maize precipitation file for Heilongjiang, followed by temperature

# %%
maize_met_1=pd.read_table('./Crop_data_files/maize_met_anoms/Maize_Spring_China_Heilongjiang_precip_anom_real_Maize.csv')
maize_met_2=pd.read_table('./Crop_data_files/maize_met_anoms/Maize_Spring_China_Heilongjiang_precip_anom_real.csv')

# %%
# change column name to year
maize_met_1.rename(columns = {'Unnamed: 0':'Year'}, inplace = True)
maize_met_2.rename(columns = {'Unnamed: 0':'Year'}, inplace = True)

# %%
maize_met_1[0::5]
# Out:
#     Year       Jan       Feb       Mar        Apr        May        Jun  \
# 0   1980  0.278885 -0.142272 -3.425027  -1.456708 -13.551594  26.137207
# 5   1985  0.017393 -0.291533 -0.413487  -8.017534 -21.461603  27.987134
# 10  1990 -0.096186  1.326500  2.353293   5.492419  -5.630065  29.783269
# 15  1995 -0.116485 -0.298341  0.789670  -4.960847  17.955771  16.123364
# 20  2000  0.038295 -0.298341  0.121115  12.307005 -20.865786 -40.719277
# 25  2005 -0.108933 -0.298341 -2.360791  32.341818  31.533797  48.175689
# 30  2010  0.552521  1.443416  1.631852   9.083635  51.559774 -47.009183
#
#           Jul         Aug        Sep        Oct       Nov       Dec
# 0  -34.326304  -21.761314  23.244760  -0.261816 -1.532116 -0.306484
# 5  -21.018332  112.348881   5.436338  -3.748350  0.805609 -0.178689
# 10 -15.958061  -12.721757  19.617757 -11.043155 -1.994033 -0.154869
# 15  16.101997  -31.599272  27.641600   2.666390 -2.751033 -0.250352
# 20  89.663416  -44.242449  14.168713  -0.526324 -0.156212 -0.161054
# 25  17.096750  -44.263800 -10.069550 -15.080515  2.721443 -0.325400
# 30 -10.670361   70.503443 -35.727175  -7.777629  1.181582  0.429674

# %%
# Compare two files 
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.heatmap(maize_met_1.pivot_table(index='Year').reindex_axis(maize_met_1.columns[1:], axis=1),cmap='Blues')
plt.subplot(1,2,2)
sns.heatmap(maize_met_2.pivot_table(index='Year').reindex_axis(maize_met_2.columns[1:], axis=1),cmap='Blues')

# %%
maize_met_1=pd.read_table('./Crop_data_files/maize_met_anoms/Maize_Spring_China_Heilongjiang_temp_anom_real_Maize.csv')
maize_met_2=pd.read_table('./Crop_data_files/maize_met_anoms/Maize_Spring_China_Heilongjiang_temp_anom_real.csv')

# %%
# change column name to year
maize_met_1.rename(columns = {'Unnamed: 0':'Year'}, inplace = True)
maize_met_2.rename(columns = {'Unnamed: 0':'Year'}, inplace = True)

# %%
# Compare two files 
import seaborn as sns
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.heatmap(maize_met_1.pivot_table(index='Year').reindex_axis(maize_met_1.columns[1:], axis=1),cmap='Blues')
plt.subplot(1,2,2)
sns.heatmap(maize_met_2.pivot_table(index='Year').reindex_axis(maize_met_2.columns[1:], axis=1),cmap='Blues')

# %% [markdown]
# ## Yield
# There also exist yield data files. We look at yield anomalies because there tends to be an increasing trend in yield over time which is not related to weather. Instead, the fluctuations around the long-term trend are related to weather events.

# %%
pd.read_table('./Crop_data_files/Maize_median_yield_anoms.csv')
# Out:
#     Unnamed: 0                           Region     1960     1961     1962  \
# 0            0        Maize_Spring_USA_Nebraska -0.06276 -0.15690  0.40794
# 1            1            Maize_Spring_USA_Iowa -0.75312 -0.04707  0.00000
# 2            2        Maize_Spring_USA_Illinois -0.69036 -0.18828  0.31380
# 3            3         Maize_Spring_USA_Indiana -0.37656 -0.25104  0.50208
# 4            4       Maize_Spring_USA_Minnesota -0.34518  0.15690  0.00000
# 5            5            Maize_Spring_USA_Ohio -0.37656 -0.06276  0.12552
# 6            6         Maize_Spring_China_Jilin -0.23500  0.11935 -0.03450
# 7            7      Maize_Spring_China_Liaoning -0.49600 -0.05390  0.00000
# 8            8  Maize_Spring_China_Heilongjiang  1.41700 -0.28565  0.00000
# 9            9         Maize_Summer_China_Hebei -0.10190  0.05095  0.01090
# 10          10        Maize_Summer_China_Shanxi -0.07660 -0.16455  0.00000
# 11          11      Maize_Summer_China_Shandong -0.09110 -0.09725  0.00000
# 12          12         Maize_Summer_China_Henan  0.00000 -0.27150  0.12380
# 13          13       Maize_Summer_China_Shaanxi  0.00000 -0.21405  0.01430
# 14          14              Maize_Argentina_All      NaN  0.00000  0.10950
# 15          15               Maize_Bulgaria_All      NaN -0.14550 -0.11705
# 16          16                 Maize_Canada_All      NaN  0.00000  0.09495
# 17          17                 Maize_France_All      NaN  0.00000 -0.29295
# 18          18                Maize_Germany_All      NaN -0.33400 -0.06860
# 19          19            Maize_Netherlands_All      NaN  0.00000 -0.14400
# 20          20                 Maize_Poland_All      NaN  0.61400 -0.13665
# 21          21                Maize_Romania_All      NaN  0.00000 -0.14055
# 22          22                Maize_Ukraine_All      NaN      NaN      NaN
# 23          23                     Maize_UK_All      NaN      NaN      NaN
# 24          24                 Maize_Brazil_All      NaN  0.00310 -0.00220
# 25          25                    Maize_USA_All      NaN -0.14370  0.05615
#
#        1963     1964     1965     1966     1967   ...        2005     2006  \
# 0   0.00000 -0.40794  0.00000  0.37656  0.00000   ...     0.00000 -0.50208
# 1   0.15690 -0.15690  0.00000  0.03138 -0.03138   ...     0.12552 -0.31380
# 2   0.12552 -0.31380  0.43932 -0.50208  0.62760   ...    -1.31796 -0.75312
# 3   0.31380 -0.62760  0.50208 -0.37656 -0.12552   ...     0.00000  0.00000
# 4   0.50208 -0.18828 -0.50208  0.25104 -0.25104   ...     0.94140  0.00000
# 5   0.25104 -0.69036 -0.25104  0.31380 -0.31380   ...    -0.81588  0.56484
# 6  -0.04300  0.05020 -0.05020  0.00000  0.13240   ...     0.18101  0.58294
# 7   0.00000  0.00000  0.00000  0.00000  0.17770   ...     0.01228 -0.19889
# 8   0.07270 -0.09070 -0.00440  0.00000  0.35160   ...     0.38670  0.00000
# 9  -0.17080  0.00000  0.00000  0.15120  0.07440   ...     0.00000  0.00000
# 10  0.09990  0.30560 -0.38730  0.02570  0.00000   ...    -0.00498  0.07901
# 11  0.00000  0.00000  0.00000  0.21410  0.13420   ...     0.20345 -0.20345
# 12 -0.14270  0.26840 -0.28030  0.00000  0.06260   ...     0.00000  0.00000
# 13 -0.01430  0.00000  0.02660  0.17180 -0.02660   ...     0.15269 -0.14016
# 14 -0.11910  0.00000 -0.12250  0.20780  0.52420   ...     0.88200 -0.54950
# 15  0.23410  0.50200 -0.89490  0.66950  0.00000   ...     0.77570  0.00000
# 16 -0.66130  0.05750 -0.05750  0.00000  0.14950   ...     0.12980 -0.03710
# 17  1.53020 -1.62540 -0.07930  0.41570 -0.41570   ...    -0.46630 -0.27040
# 18  0.08350 -0.08350  0.00000  0.00000  0.00000   ...     0.08890 -1.18320
# 19  0.26190  0.00000  0.16670  0.00000 -0.20850   ...     0.00000  0.00000
# 20 -0.03790  0.27330 -0.29240 -0.09240  0.07340   ...     0.03940 -1.57200
# 21  0.00440  0.23390 -0.23830  0.31510  0.00000   ...     0.40620  0.00000
# 22      NaN      NaN      NaN      NaN      NaN   ...     0.46270 -0.16490
# 23      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 24  0.00000 -0.14600  0.07170 -0.03030  0.04590   ...    -0.34200  0.00000
# 25  0.19750 -0.30980  0.06000 -0.06000  0.03740   ...    -0.07240 -0.10080
#
#        2007     2008     2009     2010     2011      2012     2013     2014
# 0   0.00000  0.00000  1.00416  0.18828 -0.37656 -1.506240  0.28242  0.62760
# 1   0.00000  0.00000  0.62760 -0.37656  0.43932 -1.757280 -0.25104  0.87864
# 2   0.06276  0.31380  0.00000  0.00000  0.00000 -3.263520  0.65898  1.38072
# 3  -0.18828  0.18828  0.87864  0.00000 -0.69036 -3.640080  0.97278  0.69036
# 4  -1.00416  0.00000  0.75312  0.75312 -0.62760  0.376560  0.09414 -0.18828
# 5   0.00000 -1.75728  1.12968  0.43932 -0.43932 -2.510400  0.65898  0.12552
# 6  -0.18101  0.54988 -0.45689 -0.54988  0.00000  0.194480  0.08097      NaN
# 7  -0.26599  0.46488 -0.93963 -0.81114  0.00000  0.039145  0.51029      NaN
# 8  -0.98415  0.28129 -0.28129  0.00000  0.26910 -0.134550  0.07151      NaN
# 9   0.00079  0.10930 -0.04865 -0.06144  0.00000  0.004350  0.07125      NaN
# 10  0.00000  0.00000 -0.44465 -0.00768  0.00000  0.113000  0.30546      NaN
# 11  0.00000  0.02903  0.01979 -0.04882  0.01816  0.037410 -0.17756      NaN
# 12  0.05075  0.08355  0.00000 -0.08871  0.00000  0.029670 -0.00006      NaN
# 13  0.08996 -0.10249  0.01875 -0.01875  0.00000  0.090210  0.17491      NaN
# 14  1.21300  0.00000 -0.87650  1.45370  0.00000 -0.869100  0.12670  0.23720
# 15 -3.07330 -0.37800  0.00000  1.54450  0.00000 -2.571600  0.43150  1.28800
# 16  0.00000  0.55150 -0.52230  0.67620 -0.31630 -0.153800  0.30000  0.00000
# 17  0.57180  0.19850 -0.19850 -0.26960  0.88780  0.000000 -1.37010  0.96460
# 18  0.00000  0.36240  0.00000 -1.02450  0.87430  0.000000 -1.72465  0.20360
# 19  0.53190 -0.35100  1.04720 -0.56820  0.00000  0.006500 -0.39415  1.39990
# 20  0.75940  0.00000  0.00000 -0.48060  0.60090  0.760000 -0.30645  0.00000
# 21 -1.71390 -0.18980  0.00000  0.90070  0.21160 -2.307100 -0.01755  0.29290
# 22 -0.41840  0.17640  0.32840 -0.27990  1.42510 -1.364300  0.12650  0.00000
# 23      NaN      NaN      NaN      NaN      NaN       NaN      NaN      NaN
# 24  0.07070  0.29480 -0.36550  0.15600 -0.15600  0.000000  0.16270  0.00000
# 25  0.00000  0.06730  0.74530  0.00000 -0.35600 -1.848400  0.34465  0.80700
#
# [26 rows x 57 columns]

# %% [markdown]
# ## Regions
# There also exists a regions file. This contains a list of all the combinations we will be looking at, with each combination named as:
#
# "Crop" _ "Season" _ "Country" _ "State"

# %%
regions=pd.read_table('./Crop_data_files/region_names.csv')

# %%
regions[0:10]
# Out:
#    Unnamed: 0                          Name
# 0           0         Maize_Spring_USA_Ohio
# 1           1  Wheat_Spring_USA_SouthDakota
# 2           2    Maize_Spring_USA_Minnesota
# 3           3      Maize_Summer_China_Henan
# 4           4          Soybean_USA_Illinois
# 5           5         Soybean_USA_Minnesota
# 6           6       Wheat_Winter_France_All
# 7           7        Wheat_Spring_USA_Idaho
# 8           8   Rice_Mid_China_Heilongjiang
# 9           9              Soybean_USA_Iowa

# %%
print("There are "+str(len(regions))+" combinations")
# Out:
# There are 94 combinations
